# %% [markdown]
# # Comparing Prophet Drop and Forward Results
#
# Compares message delivered, average hop count, average latency, and overhead rate as Y-axis for the drop and forward strategies. Tested 400 combinations of forward strategies and drop policies from 10M buffer size to 200M buffer size. The x-axis is the buffer size in MB.

# %%
import ipyplot as ipy

IMG_WIDTH = 720

# %% [markdown]
# ### Forwarding Strategy: COIN

# %%
coin_images = [
    "COIN_delivered.png",
    "COIN_hopcount_avg.png",
    "COIN_latency_avg.png",
    "COIN_overhead_ratio.png"
]

ipy.plot_images(coin_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8xmUEj9PgdbqLgqetpqGut {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8xmUEj9PgdbqLgqetpqGut {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8xmUEj9PgdbqLgqetpqGut {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8xmUEj9PgdbqLgqetpqGut:checked ~ #ipyplot-html-viewer-textarea-8xmUEj9PgdbqLgqetpqGut {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8xmUEj9PgdbqLgqetpqGut:checked + #ipyplot-html-viewer-label-8xmUEj9PgdbqLgqetpqGut:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-8xmUEj9PgdbqLgqetpqGut">
#         <label id="ipyplot-html-viewer-label-8xmUEj9PgdbqLgqetpqGut" for="ipyplot-html-viewer-toggle-8xmUEj9PgdbqLgqetpqGut">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-8xmUEj9PgdbqLgqetpqGut" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-fHgh9aznMycmDhnp7uRx8H {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fHgh9aznMycmDhnp7uRx8H">
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-aBkbF99uxBgUnrsFdKV4YC" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_delivered.png</h4><img src="COIN_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-aBkbF99uxBgUnrsFdKV4YC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-Pon5rNnFRZVugF5zLfEqug" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_hopcount_avg.png</h4><img src="COIN_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-Pon5rNnFRZVugF5zLfEqug">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-4e8vTnQXHwWZ5cqKwJYkxS" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_latency_avg.png</h4><img src="COIN_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-4e8vTnQXHwWZ5cqKwJYkxS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-772oQibffBiLwWL6AVzruW" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_overhead_ratio.png</h4><img src="COIN_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-772oQibffBiLwWL6AVzruW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-fHgh9aznMycmDhnp7uRx8H {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fHgh9aznMycmDhnp7uRx8H">
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-aBkbF99uxBgUnrsFdKV4YC" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_delivered.png</h4><img src="COIN_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-aBkbF99uxBgUnrsFdKV4YC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-Pon5rNnFRZVugF5zLfEqug" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_hopcount_avg.png</h4><img src="COIN_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-Pon5rNnFRZVugF5zLfEqug">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-4e8vTnQXHwWZ5cqKwJYkxS" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_latency_avg.png</h4><img src="COIN_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-4e8vTnQXHwWZ5cqKwJYkxS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fHgh9aznMycmDhnp7uRx8H">
#         <div id="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-772oQibffBiLwWL6AVzruW" class="ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_overhead_ratio.png</h4><img src="COIN_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fHgh9aznMycmDhnp7uRx8H-772oQibffBiLwWL6AVzruW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTR

# %%
grtr_images = [
    "GRTR_delivered.png",
    "GRTR_hopcount_avg.png",
    "GRTR_latency_avg.png",
    "GRTR_overhead_ratio.png"
]

ipy.plot_images(grtr_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SoBeFnNv5Xtf76uXKSoJRg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SoBeFnNv5Xtf76uXKSoJRg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SoBeFnNv5Xtf76uXKSoJRg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SoBeFnNv5Xtf76uXKSoJRg:checked ~ #ipyplot-html-viewer-textarea-SoBeFnNv5Xtf76uXKSoJRg {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SoBeFnNv5Xtf76uXKSoJRg:checked + #ipyplot-html-viewer-label-SoBeFnNv5Xtf76uXKSoJRg:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-SoBeFnNv5Xtf76uXKSoJRg">
#         <label id="ipyplot-html-viewer-label-SoBeFnNv5Xtf76uXKSoJRg" for="ipyplot-html-viewer-toggle-SoBeFnNv5Xtf76uXKSoJRg">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-SoBeFnNv5Xtf76uXKSoJRg" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-8juKC79gYmKwQNsrGBqVqD {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8juKC79gYmKwQNsrGBqVqD">
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-KhUMwons2NdbEzTevgL6Re" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_delivered.png</h4><img src="GRTR_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-KhUMwons2NdbEzTevgL6Re">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-NBCNDcFPd5oPdFietU7cmX" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_hopcount_avg.png</h4><img src="GRTR_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-NBCNDcFPd5oPdFietU7cmX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-4e5xiAQbtmbvRJ8uiyTMF6" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_latency_avg.png</h4><img src="GRTR_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-4e5xiAQbtmbvRJ8uiyTMF6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-Co46DAKYL8rdyxsc626YWH" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_overhead_ratio.png</h4><img src="GRTR_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-Co46DAKYL8rdyxsc626YWH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-8juKC79gYmKwQNsrGBqVqD {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8juKC79gYmKwQNsrGBqVqD">
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-KhUMwons2NdbEzTevgL6Re" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_delivered.png</h4><img src="GRTR_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-KhUMwons2NdbEzTevgL6Re">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-NBCNDcFPd5oPdFietU7cmX" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_hopcount_avg.png</h4><img src="GRTR_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-NBCNDcFPd5oPdFietU7cmX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-4e5xiAQbtmbvRJ8uiyTMF6" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_latency_avg.png</h4><img src="GRTR_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-4e5xiAQbtmbvRJ8uiyTMF6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8juKC79gYmKwQNsrGBqVqD">
#         <div id="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-Co46DAKYL8rdyxsc626YWH" class="ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_overhead_ratio.png</h4><img src="GRTR_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8juKC79gYmKwQNsrGBqVqD-Co46DAKYL8rdyxsc626YWH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTRMax

# %%
grtrmax_images = [
    "GRTRMax_delivered.png",
    "GRTRMax_hopcount_avg.png",
    "GRTRMax_latency_avg.png",
    "GRTRMax_overhead_ratio.png"
]

ipy.plot_images(grtrmax_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-W7UkUHesXNKtpNzFj7A5su {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-W7UkUHesXNKtpNzFj7A5su {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-W7UkUHesXNKtpNzFj7A5su {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-W7UkUHesXNKtpNzFj7A5su:checked ~ #ipyplot-html-viewer-textarea-W7UkUHesXNKtpNzFj7A5su {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-W7UkUHesXNKtpNzFj7A5su:checked + #ipyplot-html-viewer-label-W7UkUHesXNKtpNzFj7A5su:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-W7UkUHesXNKtpNzFj7A5su">
#         <label id="ipyplot-html-viewer-label-W7UkUHesXNKtpNzFj7A5su" for="ipyplot-html-viewer-toggle-W7UkUHesXNKtpNzFj7A5su">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-W7UkUHesXNKtpNzFj7A5su" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-GqEBkdQyZTHNxLATS7bC5F {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-GqEBkdQyZTHNxLATS7bC5F">
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-KbQcYcKWuunJdqLH8n5iWW" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_delivered.png</h4><img src="GRTRMax_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-KbQcYcKWuunJdqLH8n5iWW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-gpZeLqcRSLjs8gLgwSaWET" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_hopcount_avg.png</h4><img src="GRTRMax_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-gpZeLqcRSLjs8gLgwSaWET">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-jC2NUwek3yLYxNPiBdWeqE" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_latency_avg.png</h4><img src="GRTRMax_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-jC2NUwek3yLYxNPiBdWeqE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-J5QLT7nkfoKaS43rXJLo3F" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_overhead_ratio.png</h4><img src="GRTRMax_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-J5QLT7nkfoKaS43rXJLo3F">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-GqEBkdQyZTHNxLATS7bC5F {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-GqEBkdQyZTHNxLATS7bC5F">
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-KbQcYcKWuunJdqLH8n5iWW" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_delivered.png</h4><img src="GRTRMax_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-KbQcYcKWuunJdqLH8n5iWW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-gpZeLqcRSLjs8gLgwSaWET" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_hopcount_avg.png</h4><img src="GRTRMax_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-gpZeLqcRSLjs8gLgwSaWET">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-jC2NUwek3yLYxNPiBdWeqE" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_latency_avg.png</h4><img src="GRTRMax_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-jC2NUwek3yLYxNPiBdWeqE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GqEBkdQyZTHNxLATS7bC5F">
#         <div id="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-J5QLT7nkfoKaS43rXJLo3F" class="ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_overhead_ratio.png</h4><img src="GRTRMax_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GqEBkdQyZTHNxLATS7bC5F-J5QLT7nkfoKaS43rXJLo3F">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTRSort

# %%
grtrsort_images = [
    "GRTRSort_delivered.png",
    "GRTRSort_hopcount_avg.png",
    "GRTRSort_latency_avg.png",
    "GRTRSort_overhead_ratio.png"
]

ipy.plot_images(grtrsort_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RjzWU5TNQSNn829smyPzPt {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RjzWU5TNQSNn829smyPzPt {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RjzWU5TNQSNn829smyPzPt {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RjzWU5TNQSNn829smyPzPt:checked ~ #ipyplot-html-viewer-textarea-RjzWU5TNQSNn829smyPzPt {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RjzWU5TNQSNn829smyPzPt:checked + #ipyplot-html-viewer-label-RjzWU5TNQSNn829smyPzPt:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-RjzWU5TNQSNn829smyPzPt">
#         <label id="ipyplot-html-viewer-label-RjzWU5TNQSNn829smyPzPt" for="ipyplot-html-viewer-toggle-RjzWU5TNQSNn829smyPzPt">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-RjzWU5TNQSNn829smyPzPt" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-bBYazwuZuk7D3jaEVmJuy9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9 {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bBYazwuZuk7D3jaEVmJuy9">
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-JTD2xvxzFnb259P5HxunxA" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_delivered.png</h4><img src="GRTRSort_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-JTD2xvxzFnb259P5HxunxA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-LRZzBEYy2dZCwXALnBty3K" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_hopcount_avg.png</h4><img src="GRTRSort_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-LRZzBEYy2dZCwXALnBty3K">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-5fYkNomFmk7XerU2QXddV3" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_latency_avg.png</h4><img src="GRTRSort_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-5fYkNomFmk7XerU2QXddV3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-bUnkjAifLoufr468G37aiC" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_overhead_ratio.png</h4><img src="GRTRSort_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-bUnkjAifLoufr468G37aiC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-bBYazwuZuk7D3jaEVmJuy9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9 {
#             width: 720px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 {
#             width: 720px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 img {
#             width: 720px;
#         }
#
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bBYazwuZuk7D3jaEVmJuy9">
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-JTD2xvxzFnb259P5HxunxA" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_delivered.png</h4><img src="GRTRSort_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-JTD2xvxzFnb259P5HxunxA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-LRZzBEYy2dZCwXALnBty3K" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_hopcount_avg.png</h4><img src="GRTRSort_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-LRZzBEYy2dZCwXALnBty3K">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-5fYkNomFmk7XerU2QXddV3" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_latency_avg.png</h4><img src="GRTRSort_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-5fYkNomFmk7XerU2QXddV3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bBYazwuZuk7D3jaEVmJuy9">
#         <div id="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-bUnkjAifLoufr468G37aiC" class="ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_overhead_ratio.png</h4><img src="GRTRSort_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bBYazwuZuk7D3jaEVmJuy9-bUnkjAifLoufr468G37aiC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
