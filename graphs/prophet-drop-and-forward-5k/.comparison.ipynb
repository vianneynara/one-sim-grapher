# %% [markdown]
# # Comparing Prophet Drop and Forward Results
#
# Compares message delivered, average hop count, average latency, and overhead rate as Y-axis for the drop and forward strategies. Tested 400 combinations of forward strategies and drop policies from 10M buffer size to 200M buffer size. The x-axis is the buffer size in MB.

# %%
import ipyplot as ipy

IMG_WIDTH = 360

# %% [markdown]
# ### Forwarding Strategy: COIN

# %%
coin_images = [
    "COIN_delivered.png",
    "COIN_hopcount_avg.png",
    "COIN_latency_avg.png",
    "COIN_overhead_ratio.png"
]

ipy.plot_images(coin_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-6mgVpRhVHQY3DMaxQ4HPPR {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-6mgVpRhVHQY3DMaxQ4HPPR {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-6mgVpRhVHQY3DMaxQ4HPPR {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6mgVpRhVHQY3DMaxQ4HPPR:checked ~ #ipyplot-html-viewer-textarea-6mgVpRhVHQY3DMaxQ4HPPR {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6mgVpRhVHQY3DMaxQ4HPPR:checked + #ipyplot-html-viewer-label-6mgVpRhVHQY3DMaxQ4HPPR:after {
# ...

# %% [markdown]
# ### Forwarding Strategy: GRTR

# %%
grtr_images = [
    "GRTR_delivered.png",
    "GRTR_hopcount_avg.png",
    "GRTR_latency_avg.png",
    "GRTR_overhead_ratio.png"
]

ipy.plot_images(grtr_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Fa8vTPSdaxUGxLLN9WdjgB {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Fa8vTPSdaxUGxLLN9WdjgB {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Fa8vTPSdaxUGxLLN9WdjgB {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Fa8vTPSdaxUGxLLN9WdjgB:checked ~ #ipyplot-html-viewer-textarea-Fa8vTPSdaxUGxLLN9WdjgB {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Fa8vTPSdaxUGxLLN9WdjgB:checked + #ipyplot-html-viewer-label-Fa8vTPSdaxUGxLLN9WdjgB:after {
# ...

# %% [markdown]
# ### Forwarding Strategy: GRTRMax

# %%
grtrmax_images = [
    "GRTRMax_delivered.png",
    "GRTRMax_hopcount_avg.png",
    "GRTRMax_latency_avg.png",
    "GRTRMax_overhead_ratio.png"
]

ipy.plot_images(grtrmax_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-F8dxUXErgBgUCe2zrfSfcE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-F8dxUXErgBgUCe2zrfSfcE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-F8dxUXErgBgUCe2zrfSfcE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-F8dxUXErgBgUCe2zrfSfcE:checked ~ #ipyplot-html-viewer-textarea-F8dxUXErgBgUCe2zrfSfcE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-F8dxUXErgBgUCe2zrfSfcE:checked + #ipyplot-html-viewer-label-F8dxUXErgBgUCe2zrfSfcE:after {
# ...

# %% [markdown]
# ### Forwarding Strategy: GRTRSort

# %%
grtrsort_images = [
    "GRTRSort_delivered.png",
    "GRTRSort_hopcount_avg.png",
    "GRTRSort_latency_avg.png",
    "GRTRSort_overhead_ratio.png"
]

ipy.plot_images(grtrsort_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nmuzEPJCgSnWZgvixVo6op {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nmuzEPJCgSnWZgvixVo6op {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nmuzEPJCgSnWZgvixVo6op {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nmuzEPJCgSnWZgvixVo6op:checked ~ #ipyplot-html-viewer-textarea-nmuzEPJCgSnWZgvixVo6op {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nmuzEPJCgSnWZgvixVo6op:checked + #ipyplot-html-viewer-label-nmuzEPJCgSnWZgvixVo6op:after {
# ...
