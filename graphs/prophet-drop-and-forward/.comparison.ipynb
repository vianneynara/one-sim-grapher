# %% [markdown]
# # Comparing Prophet Drop and Forward Results
#
# Compares message delivered, average hop count, average latency, and overhead rate as Y-axis for the drop and forward strategies. Tested 400 combinations of forward strategies and drop policies from 10M buffer size to 200M buffer size. The x-axis is the buffer size in MB.

# %%
import ipyplot as ipy

# %% [markdown]
# ### Forwarding Strategy: COIN

# %%
coin_images = [
    "COIN_delivered.png",
    "COIN_hopcount_avg.png",
    "COIN_latency_avg.png",
    "COIN_overhead_ratio.png"
]

ipy.plot_images(coin_images, img_width=360)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-9kwnmT43FWmS4MtcLJkeFi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9kwnmT43FWmS4MtcLJkeFi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9kwnmT43FWmS4MtcLJkeFi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9kwnmT43FWmS4MtcLJkeFi:checked ~ #ipyplot-html-viewer-textarea-9kwnmT43FWmS4MtcLJkeFi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9kwnmT43FWmS4MtcLJkeFi:checked + #ipyplot-html-viewer-label-9kwnmT43FWmS4MtcLJkeFi:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-9kwnmT43FWmS4MtcLJkeFi">
#         <label id="ipyplot-html-viewer-label-9kwnmT43FWmS4MtcLJkeFi" for="ipyplot-html-viewer-toggle-9kwnmT43FWmS4MtcLJkeFi">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-9kwnmT43FWmS4MtcLJkeFi" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-F4judDUkBMzc5euJCjfx2e {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-F4judDUkBMzc5euJCjfx2e]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-F4judDUkBMzc5euJCjfx2e]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-F4judDUkBMzc5euJCjfx2e]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-F4judDUkBMzc5euJCjfx2e">
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-h5kE6XZ2jZDn7nt5VYyYrr" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_delivered.png</h4><img src="COIN_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-h5kE6XZ2jZDn7nt5VYyYrr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CAC4zBRZTTcm2SQL4iWDmo" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_hopcount_avg.png</h4><img src="COIN_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CAC4zBRZTTcm2SQL4iWDmo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-Hg2dFRgL6pZQheoE4RjvUR" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_latency_avg.png</h4><img src="COIN_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-Hg2dFRgL6pZQheoE4RjvUR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CRNjAABUhZgndi6d6kum7N" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_overhead_ratio.png</h4><img src="COIN_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CRNjAABUhZgndi6d6kum7N">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-F4judDUkBMzc5euJCjfx2e {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-F4judDUkBMzc5euJCjfx2e span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-F4judDUkBMzc5euJCjfx2e]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-F4judDUkBMzc5euJCjfx2e]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-F4judDUkBMzc5euJCjfx2e]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-F4judDUkBMzc5euJCjfx2e">
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-h5kE6XZ2jZDn7nt5VYyYrr" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_delivered.png</h4><img src="COIN_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-h5kE6XZ2jZDn7nt5VYyYrr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CAC4zBRZTTcm2SQL4iWDmo" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_hopcount_avg.png</h4><img src="COIN_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CAC4zBRZTTcm2SQL4iWDmo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-Hg2dFRgL6pZQheoE4RjvUR" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_latency_avg.png</h4><img src="COIN_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-Hg2dFRgL6pZQheoE4RjvUR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-F4judDUkBMzc5euJCjfx2e">
#         <div id="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CRNjAABUhZgndi6d6kum7N" class="ipyplot-content-div-F4judDUkBMzc5euJCjfx2e">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_overhead_ratio.png</h4><img src="COIN_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-F4judDUkBMzc5euJCjfx2e-CRNjAABUhZgndi6d6kum7N">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTR

# %%
grtr_images = [
    "GRTR_delivered.png",
    "GRTR_hopcount_avg.png",
    "GRTR_latency_avg.png",
    "GRTR_overhead_ratio.png"
]

ipy.plot_images(grtr_images, img_width=360)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-XALQ6FSbjeFq7bG4BKVYeo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-XALQ6FSbjeFq7bG4BKVYeo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-XALQ6FSbjeFq7bG4BKVYeo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-XALQ6FSbjeFq7bG4BKVYeo:checked ~ #ipyplot-html-viewer-textarea-XALQ6FSbjeFq7bG4BKVYeo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-XALQ6FSbjeFq7bG4BKVYeo:checked + #ipyplot-html-viewer-label-XALQ6FSbjeFq7bG4BKVYeo:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-XALQ6FSbjeFq7bG4BKVYeo">
#         <label id="ipyplot-html-viewer-label-XALQ6FSbjeFq7bG4BKVYeo" for="ipyplot-html-viewer-toggle-XALQ6FSbjeFq7bG4BKVYeo">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-XALQ6FSbjeFq7bG4BKVYeo" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-mAs33JFsWrUKeo6HWKAEwN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mAs33JFsWrUKeo6HWKAEwN">
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-87fBMm7HAobVBeqfb8VnnL" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_delivered.png</h4><img src="GRTR_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-87fBMm7HAobVBeqfb8VnnL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Ht9Rp7cymw6sjUN2yZWFnq" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_hopcount_avg.png</h4><img src="GRTR_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Ht9Rp7cymw6sjUN2yZWFnq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-63x3wRvwdhFoTfcjPFakin" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_latency_avg.png</h4><img src="GRTR_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-63x3wRvwdhFoTfcjPFakin">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Q6zZ5jCmAbHmRzuw5RYhJE" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_overhead_ratio.png</h4><img src="GRTR_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Q6zZ5jCmAbHmRzuw5RYhJE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-mAs33JFsWrUKeo6HWKAEwN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mAs33JFsWrUKeo6HWKAEwN">
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-87fBMm7HAobVBeqfb8VnnL" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_delivered.png</h4><img src="GRTR_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-87fBMm7HAobVBeqfb8VnnL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Ht9Rp7cymw6sjUN2yZWFnq" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_hopcount_avg.png</h4><img src="GRTR_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Ht9Rp7cymw6sjUN2yZWFnq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-63x3wRvwdhFoTfcjPFakin" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_latency_avg.png</h4><img src="GRTR_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-63x3wRvwdhFoTfcjPFakin">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mAs33JFsWrUKeo6HWKAEwN">
#         <div id="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Q6zZ5jCmAbHmRzuw5RYhJE" class="ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_overhead_ratio.png</h4><img src="GRTR_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mAs33JFsWrUKeo6HWKAEwN-Q6zZ5jCmAbHmRzuw5RYhJE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTRMax

# %%
grtrmax_images = [
    "GRTRMax_delivered.png",
    "GRTRMax_hopcount_avg.png",
    "GRTRMax_latency_avg.png",
    "GRTRMax_overhead_ratio.png"
]

ipy.plot_images(grtrmax_images, img_width=360)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-EKg5rax5C9ifDPQWqbGhHx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EKg5rax5C9ifDPQWqbGhHx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EKg5rax5C9ifDPQWqbGhHx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EKg5rax5C9ifDPQWqbGhHx:checked ~ #ipyplot-html-viewer-textarea-EKg5rax5C9ifDPQWqbGhHx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EKg5rax5C9ifDPQWqbGhHx:checked + #ipyplot-html-viewer-label-EKg5rax5C9ifDPQWqbGhHx:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-EKg5rax5C9ifDPQWqbGhHx">
#         <label id="ipyplot-html-viewer-label-EKg5rax5C9ifDPQWqbGhHx" for="ipyplot-html-viewer-toggle-EKg5rax5C9ifDPQWqbGhHx">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-EKg5rax5C9ifDPQWqbGhHx" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-fhKywiJfDiFzXqemasVQNX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fhKywiJfDiFzXqemasVQNX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fhKywiJfDiFzXqemasVQNX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fhKywiJfDiFzXqemasVQNX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fhKywiJfDiFzXqemasVQNX">
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VVWVgC8AiXa7DtmiRBN7yW" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_delivered.png</h4><img src="GRTRMax_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VVWVgC8AiXa7DtmiRBN7yW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-gjPJGe5HYZ4p6VkPDFo3ed" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_hopcount_avg.png</h4><img src="GRTRMax_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-gjPJGe5HYZ4p6VkPDFo3ed">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VdvjwzBzHm86bzAMjPWMVc" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_latency_avg.png</h4><img src="GRTRMax_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VdvjwzBzHm86bzAMjPWMVc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-dVfBQJrmfWy43Hk2QpUx4p" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_overhead_ratio.png</h4><img src="GRTRMax_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-dVfBQJrmfWy43Hk2QpUx4p">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-fhKywiJfDiFzXqemasVQNX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fhKywiJfDiFzXqemasVQNX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fhKywiJfDiFzXqemasVQNX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fhKywiJfDiFzXqemasVQNX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fhKywiJfDiFzXqemasVQNX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fhKywiJfDiFzXqemasVQNX">
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VVWVgC8AiXa7DtmiRBN7yW" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_delivered.png</h4><img src="GRTRMax_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VVWVgC8AiXa7DtmiRBN7yW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-gjPJGe5HYZ4p6VkPDFo3ed" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_hopcount_avg.png</h4><img src="GRTRMax_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-gjPJGe5HYZ4p6VkPDFo3ed">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VdvjwzBzHm86bzAMjPWMVc" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_latency_avg.png</h4><img src="GRTRMax_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-VdvjwzBzHm86bzAMjPWMVc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fhKywiJfDiFzXqemasVQNX">
#         <div id="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-dVfBQJrmfWy43Hk2QpUx4p" class="ipyplot-content-div-fhKywiJfDiFzXqemasVQNX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_overhead_ratio.png</h4><img src="GRTRMax_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fhKywiJfDiFzXqemasVQNX-dVfBQJrmfWy43Hk2QpUx4p">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTRSort

# %%
grtrsort_images = [
    "GRTRSort_delivered.png",
    "GRTRSort_hopcount_avg.png",
    "GRTRSort_latency_avg.png",
    "GRTRSort_overhead_ratio.png"
]

ipy.plot_images(grtrsort_images, img_width=360)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-gEYZ4dDJeTCmh4SovFHQ5i {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gEYZ4dDJeTCmh4SovFHQ5i {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gEYZ4dDJeTCmh4SovFHQ5i {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gEYZ4dDJeTCmh4SovFHQ5i:checked ~ #ipyplot-html-viewer-textarea-gEYZ4dDJeTCmh4SovFHQ5i {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gEYZ4dDJeTCmh4SovFHQ5i:checked + #ipyplot-html-viewer-label-gEYZ4dDJeTCmh4SovFHQ5i:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-gEYZ4dDJeTCmh4SovFHQ5i">
#         <label id="ipyplot-html-viewer-label-gEYZ4dDJeTCmh4SovFHQ5i" for="ipyplot-html-viewer-toggle-gEYZ4dDJeTCmh4SovFHQ5i">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-gEYZ4dDJeTCmh4SovFHQ5i" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-DArxQN8H2JHjJ2EraHzTmU {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-DArxQN8H2JHjJ2EraHzTmU">
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-inZdUFaatit2gucufTBXvL" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_delivered.png</h4><img src="GRTRSort_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-inZdUFaatit2gucufTBXvL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-dCpn2urup43p4sC8U2nFrG" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_hopcount_avg.png</h4><img src="GRTRSort_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-dCpn2urup43p4sC8U2nFrG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-nttEhe2sqEaYsdiLx3iVLN" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_latency_avg.png</h4><img src="GRTRSort_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-nttEhe2sqEaYsdiLx3iVLN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-NKo2qiqsXMp4LjNwgMwFxG" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_overhead_ratio.png</h4><img src="GRTRSort_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-NKo2qiqsXMp4LjNwgMwFxG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-DArxQN8H2JHjJ2EraHzTmU {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-DArxQN8H2JHjJ2EraHzTmU">
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-inZdUFaatit2gucufTBXvL" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_delivered.png</h4><img src="GRTRSort_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-inZdUFaatit2gucufTBXvL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-dCpn2urup43p4sC8U2nFrG" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_hopcount_avg.png</h4><img src="GRTRSort_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-dCpn2urup43p4sC8U2nFrG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-nttEhe2sqEaYsdiLx3iVLN" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_latency_avg.png</h4><img src="GRTRSort_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-nttEhe2sqEaYsdiLx3iVLN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DArxQN8H2JHjJ2EraHzTmU">
#         <div id="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-NKo2qiqsXMp4LjNwgMwFxG" class="ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_overhead_ratio.png</h4><img src="GRTRSort_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DArxQN8H2JHjJ2EraHzTmU-NKo2qiqsXMp4LjNwgMwFxG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
