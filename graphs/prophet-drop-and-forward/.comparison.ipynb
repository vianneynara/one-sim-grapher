# %% [markdown]
# # Comparing Prophet Drop and Forward Results
#
# Compares message delivered, average hop count, average latency, and overhead rate as Y-axis for the drop and forward strategies. Tested 400 combinations of forward strategies and drop policies from 10M buffer size to 200M buffer size. The x-axis is the buffer size in MB.

# %%
import ipyplot as ipy

IMG_WIDTH = 360

# %% [markdown]
# ### Forwarding Strategy: COIN

# %%
coin_images = [
    "COIN_delivered.png",
    "COIN_hopcount_avg.png",
    "COIN_latency_avg.png",
    "COIN_overhead_ratio.png"
]

ipy.plot_images(coin_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nMcC2HF8EYpXXcM6fxJZVW {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nMcC2HF8EYpXXcM6fxJZVW {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nMcC2HF8EYpXXcM6fxJZVW {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nMcC2HF8EYpXXcM6fxJZVW:checked ~ #ipyplot-html-viewer-textarea-nMcC2HF8EYpXXcM6fxJZVW {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nMcC2HF8EYpXXcM6fxJZVW:checked + #ipyplot-html-viewer-label-nMcC2HF8EYpXXcM6fxJZVW:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-nMcC2HF8EYpXXcM6fxJZVW">
#         <label id="ipyplot-html-viewer-label-nMcC2HF8EYpXXcM6fxJZVW" for="ipyplot-html-viewer-toggle-nMcC2HF8EYpXXcM6fxJZVW">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-nMcC2HF8EYpXXcM6fxJZVW" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-4Uc6UDQSWdFcr6zXKhyAu6 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6 {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-4Uc6UDQSWdFcr6zXKhyAu6">
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-NgDPhuj3KKsFEHBnKAnLRv" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_delivered.png</h4><img src="COIN_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-NgDPhuj3KKsFEHBnKAnLRv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-2fcRdCLaa2kV7fp8gteFtx" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_hopcount_avg.png</h4><img src="COIN_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-2fcRdCLaa2kV7fp8gteFtx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-BUvQShJnHk5cAcqyFz7KWv" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_latency_avg.png</h4><img src="COIN_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-BUvQShJnHk5cAcqyFz7KWv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-59zrssnebQqtjAXnjBvQeA" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_overhead_ratio.png</h4><img src="COIN_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-59zrssnebQqtjAXnjBvQeA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-4Uc6UDQSWdFcr6zXKhyAu6 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6 {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-4Uc6UDQSWdFcr6zXKhyAu6">
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-NgDPhuj3KKsFEHBnKAnLRv" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_delivered.png</h4><img src="COIN_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-NgDPhuj3KKsFEHBnKAnLRv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-2fcRdCLaa2kV7fp8gteFtx" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_hopcount_avg.png</h4><img src="COIN_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-2fcRdCLaa2kV7fp8gteFtx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-BUvQShJnHk5cAcqyFz7KWv" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_latency_avg.png</h4><img src="COIN_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-BUvQShJnHk5cAcqyFz7KWv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4Uc6UDQSWdFcr6zXKhyAu6">
#         <div id="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-59zrssnebQqtjAXnjBvQeA" class="ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">COIN_overhead_ratio.png</h4><img src="COIN_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4Uc6UDQSWdFcr6zXKhyAu6-59zrssnebQqtjAXnjBvQeA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTR

# %%
grtr_images = [
    "GRTR_delivered.png",
    "GRTR_hopcount_avg.png",
    "GRTR_latency_avg.png",
    "GRTR_overhead_ratio.png"
]

ipy.plot_images(grtr_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-9XL33G46nCBzmvMUi73yQD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9XL33G46nCBzmvMUi73yQD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9XL33G46nCBzmvMUi73yQD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9XL33G46nCBzmvMUi73yQD:checked ~ #ipyplot-html-viewer-textarea-9XL33G46nCBzmvMUi73yQD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9XL33G46nCBzmvMUi73yQD:checked + #ipyplot-html-viewer-label-9XL33G46nCBzmvMUi73yQD:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-9XL33G46nCBzmvMUi73yQD">
#         <label id="ipyplot-html-viewer-label-9XL33G46nCBzmvMUi73yQD" for="ipyplot-html-viewer-toggle-9XL33G46nCBzmvMUi73yQD">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-9XL33G46nCBzmvMUi73yQD" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-m75rwVKkLpaH7C2iKvSZUz {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-m75rwVKkLpaH7C2iKvSZUz">
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-8J4hdb273TfSyV7y6b7JUi" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_delivered.png</h4><img src="GRTR_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-8J4hdb273TfSyV7y6b7JUi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-fRFW5gw6WvHZSZMrWoXnuG" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_hopcount_avg.png</h4><img src="GRTR_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-fRFW5gw6WvHZSZMrWoXnuG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-BTd7x6G7aj6kYwKrRugEs4" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_latency_avg.png</h4><img src="GRTR_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-BTd7x6G7aj6kYwKrRugEs4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-kDWE5syYnhZ5Yq4FaKHBLj" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_overhead_ratio.png</h4><img src="GRTR_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-kDWE5syYnhZ5Yq4FaKHBLj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-m75rwVKkLpaH7C2iKvSZUz {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-m75rwVKkLpaH7C2iKvSZUz">
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-8J4hdb273TfSyV7y6b7JUi" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_delivered.png</h4><img src="GRTR_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-8J4hdb273TfSyV7y6b7JUi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-fRFW5gw6WvHZSZMrWoXnuG" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_hopcount_avg.png</h4><img src="GRTR_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-fRFW5gw6WvHZSZMrWoXnuG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-BTd7x6G7aj6kYwKrRugEs4" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_latency_avg.png</h4><img src="GRTR_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-BTd7x6G7aj6kYwKrRugEs4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-m75rwVKkLpaH7C2iKvSZUz">
#         <div id="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-kDWE5syYnhZ5Yq4FaKHBLj" class="ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTR_overhead_ratio.png</h4><img src="GRTR_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-m75rwVKkLpaH7C2iKvSZUz-kDWE5syYnhZ5Yq4FaKHBLj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTRMax

# %%
grtrmax_images = [
    "GRTRMax_delivered.png",
    "GRTRMax_hopcount_avg.png",
    "GRTRMax_latency_avg.png",
    "GRTRMax_overhead_ratio.png"
]

ipy.plot_images(grtrmax_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-GKGRMaxwogfmoHBAG3y2y8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-GKGRMaxwogfmoHBAG3y2y8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-GKGRMaxwogfmoHBAG3y2y8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-GKGRMaxwogfmoHBAG3y2y8:checked ~ #ipyplot-html-viewer-textarea-GKGRMaxwogfmoHBAG3y2y8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-GKGRMaxwogfmoHBAG3y2y8:checked + #ipyplot-html-viewer-label-GKGRMaxwogfmoHBAG3y2y8:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-GKGRMaxwogfmoHBAG3y2y8">
#         <label id="ipyplot-html-viewer-label-GKGRMaxwogfmoHBAG3y2y8" for="ipyplot-html-viewer-toggle-GKGRMaxwogfmoHBAG3y2y8">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-GKGRMaxwogfmoHBAG3y2y8" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-DrvyrjzkLv8mKpqFG38ZDS {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-DrvyrjzkLv8mKpqFG38ZDS">
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-PaRD5MLuCPXWrW2cvuj2Se" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_delivered.png</h4><img src="GRTRMax_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-PaRD5MLuCPXWrW2cvuj2Se">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-KETW88pvqAoM63XRmToYVK" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_hopcount_avg.png</h4><img src="GRTRMax_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-KETW88pvqAoM63XRmToYVK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-DL7eWtjmWpUciyLw83YsDd" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_latency_avg.png</h4><img src="GRTRMax_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-DL7eWtjmWpUciyLw83YsDd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-R7hrekDkB5gRQMJ3mPbAh4" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_overhead_ratio.png</h4><img src="GRTRMax_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-R7hrekDkB5gRQMJ3mPbAh4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-DrvyrjzkLv8mKpqFG38ZDS {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-DrvyrjzkLv8mKpqFG38ZDS">
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-PaRD5MLuCPXWrW2cvuj2Se" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_delivered.png</h4><img src="GRTRMax_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-PaRD5MLuCPXWrW2cvuj2Se">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-KETW88pvqAoM63XRmToYVK" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_hopcount_avg.png</h4><img src="GRTRMax_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-KETW88pvqAoM63XRmToYVK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-DL7eWtjmWpUciyLw83YsDd" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_latency_avg.png</h4><img src="GRTRMax_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-DL7eWtjmWpUciyLw83YsDd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DrvyrjzkLv8mKpqFG38ZDS">
#         <div id="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-R7hrekDkB5gRQMJ3mPbAh4" class="ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRMax_overhead_ratio.png</h4><img src="GRTRMax_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DrvyrjzkLv8mKpqFG38ZDS-R7hrekDkB5gRQMJ3mPbAh4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Forwarding Strategy: GRTRSort

# %%
grtrsort_images = [
    "GRTRSort_delivered.png",
    "GRTRSort_hopcount_avg.png",
    "GRTRSort_latency_avg.png",
    "GRTRSort_overhead_ratio.png"
]

ipy.plot_images(grtrsort_images, img_width=IMG_WIDTH)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Gmp22NCdznHy4x8GGwZjph {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Gmp22NCdznHy4x8GGwZjph {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Gmp22NCdznHy4x8GGwZjph {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Gmp22NCdznHy4x8GGwZjph:checked ~ #ipyplot-html-viewer-textarea-Gmp22NCdznHy4x8GGwZjph {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Gmp22NCdznHy4x8GGwZjph:checked + #ipyplot-html-viewer-label-Gmp22NCdznHy4x8GGwZjph:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Gmp22NCdznHy4x8GGwZjph">
#         <label id="ipyplot-html-viewer-label-Gmp22NCdznHy4x8GGwZjph" for="ipyplot-html-viewer-toggle-Gmp22NCdznHy4x8GGwZjph">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Gmp22NCdznHy4x8GGwZjph" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-jimggLD6MLeDrXZswquUcw {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jimggLD6MLeDrXZswquUcw]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jimggLD6MLeDrXZswquUcw]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jimggLD6MLeDrXZswquUcw]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jimggLD6MLeDrXZswquUcw">
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-DoxXXBSCnigRJ5nma9roKm" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_delivered.png</h4><img src="GRTRSort_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-DoxXXBSCnigRJ5nma9roKm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-7Z3yP4EA5xLSSpukTpBYYx" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_hopcount_avg.png</h4><img src="GRTRSort_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-7Z3yP4EA5xLSSpukTpBYYx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-Ynt9UX6nUbMsfcrPNiuqyW" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_latency_avg.png</h4><img src="GRTRSort_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-Ynt9UX6nUbMsfcrPNiuqyW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-d9rFfsk2mvxZoZKp8g7bSd" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_overhead_ratio.png</h4><img src="GRTRSort_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-d9rFfsk2mvxZoZKp8g7bSd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-jimggLD6MLeDrXZswquUcw {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw {
#             width: 360px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw {
#             width: 360px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw img {
#             width: 360px;
#         }
#
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jimggLD6MLeDrXZswquUcw span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jimggLD6MLeDrXZswquUcw]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jimggLD6MLeDrXZswquUcw]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jimggLD6MLeDrXZswquUcw]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jimggLD6MLeDrXZswquUcw">
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-DoxXXBSCnigRJ5nma9roKm" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_delivered.png</h4><img src="GRTRSort_delivered.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-DoxXXBSCnigRJ5nma9roKm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-7Z3yP4EA5xLSSpukTpBYYx" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_hopcount_avg.png</h4><img src="GRTRSort_hopcount_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-7Z3yP4EA5xLSSpukTpBYYx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-Ynt9UX6nUbMsfcrPNiuqyW" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_latency_avg.png</h4><img src="GRTRSort_latency_avg.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-Ynt9UX6nUbMsfcrPNiuqyW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jimggLD6MLeDrXZswquUcw">
#         <div id="ipyplot-content-div-jimggLD6MLeDrXZswquUcw-d9rFfsk2mvxZoZKp8g7bSd" class="ipyplot-content-div-jimggLD6MLeDrXZswquUcw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">GRTRSort_overhead_ratio.png</h4><img src="GRTRSort_overhead_ratio.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jimggLD6MLeDrXZswquUcw-d9rFfsk2mvxZoZKp8g7bSd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
